# %%
# Experiment 1 - Introduction To Python
# Navya Bhargava
# 25070123079

x,y,z = "Apple","Orange","Cherry"
print(x,y,z,sep="\n")
# Out:
# Apple
# Orange
# Cherry

# %%
x,y,z,w = 2,2.5,"Navya",True
print (type(x),type(y),type(z),type(w),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b = 10,5
print("Add =",a+b,"\nSub=",a-b,"\nMulti=",a*b,"\nDiv=",a/b,"\nExp=",a**b)
# Out:
# Add = 15
# Sub= 5
# Multi= 50
# Div= 2.0
# Exp= 100000

# %%
a=int(input("Enter the value of a="))
b = int(input("Enter the value of b="))
print("Add =",a+b,"\nSub=",a-b,"\nMulti=",a*b,"\nDiv=",a/b,"\nExp=",a**b)
# Out:
# Enter the value of a=3
# Enter thr value of b=6
# Add = 9
# Sub= -3
# Multi= 18
# Div= 0.5
# Exp= 729

# %%
r = float(input("Enter radius of circle= "))
import math
print("The area is=",math.pi*r*r)
# Out:
# Enter radius of circle= 3
# The area is= 28.274333882308138

# %%
import math
print (math.log10(10))
# Out:
# 1.0

# %%
import math
print(math.sin(math.pi/6))
# Out:
# 0.49999999999999994

# %%
a,b = 10,5
if a>b:
    print("a is greater")
else:
   print("b is greater")
# Out:
# a is greater

# %%
a=int(input("Enter the value of a="))
b = int(input("Enter the value of b="))
if a>b:
    print("a is greater")
else:
   print("b is greater")
# Out:
# Enter the value of a=3
# Enter the value of b=5
# b is greater
